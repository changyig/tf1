# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import matplotlib.pyplot as plt
import numpy as np

# %%
mnist=input_data.read_data_sets("../MNIST_data/",one_hot=True)
print(mnist.train.images.shape,mnist.train.labels.shape)
# Out:
# Extracting ../MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../MNIST_data/t10k-labels-idx1-ubyte.gz
# (55000, 784) (55000, 10)

# %%
sess = tf.InteractiveSession()
x = tf.placeholder("float", shape=[None, 784])
y_ = tf.placeholder("float", shape=[None, 10])

# %%
def weight_variable(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)
def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)
def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')
def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

# %%
#第一层卷积
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])
x_image = tf.reshape(x, [-1,28,28,1])
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)
#第二层卷积
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)
#密集连接
W_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])
h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)
#dropout
keep_prob = tf.placeholder("float")
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)
#输出层
W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

y_conv=tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)

# %%
cross_entropy = tf.reduce_mean(-tf.reduce_sum(y_*tf.log(y_conv)))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
corrcet_result=tf.argmax(y_conv,1)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
sess.run(tf.global_variables_initializer())
for i in range(2000):
  batch = mnist.train.next_batch(10)
  if i%10 == 0:
    train_accuracy = accuracy.eval(feed_dict={
        x:batch[0], y_: batch[1], keep_prob: 1.0})
    cross_entropy_value=cross_entropy.eval(feed_dict={
        x:batch[0], y_: batch[1], keep_prob: 1.0})
    print("step %d, accuracy: %g , training accuracy %g"%(i,cross_entropy_value, train_accuracy))
#     print("step %d,  training accuracy %g"%(i, train_accuracy))
  train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})

# print(accuracy.eval(feed_dict={
#     x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0}))
# Out:
# step 0, accuracy: 129.228 , training accuracy 0
# step 10, accuracy: 33.9728 , training accuracy 0
# step 20, accuracy: 27.097 , training accuracy 0.4
# step 30, accuracy: 27.0373 , training accuracy 0.2
# step 40, accuracy: 15.1939 , training accuracy 0.4
# step 50, accuracy: 23.0152 , training accuracy 0.4
# step 60, accuracy: 12.2679 , training accuracy 0.6
# step 70, accuracy: 11.95 , training accuracy 0.6
# step 80, accuracy: 12.528 , training accuracy 0.4
# step 90, accuracy: 6.90253 , training accuracy 0.8
# step 100, accuracy: 9.05488 , training accuracy 0.7
# step 110, accuracy: 12.934 , training accuracy 0.5
# step 120, accuracy: 7.44828 , training accuracy 0.8
# step 130, accuracy: 2.56771 , training accuracy 1
# step 140, accuracy: 4.17629 , training accuracy 0.9
# step 150, accuracy: 6.30335 , training accuracy 0.8
# step 160, accuracy: 8.35437 , training accuracy 0.7
# step 170, accuracy: 2.93065 , training accuracy 0.9
# step 180, accuracy: 7.07591 , training accuracy 0.8
# step 190, accuracy: 7.07415 , training accuracy 0.8
# step 200, accuracy: 5.18991 , training accuracy 0.9
# step 210, accuracy: 6.20931 , training accuracy 0.7
# step 220, accuracy: 3.79698 , training accuracy 0.9
# step 230, accuracy: 3.65759 , training accuracy 0.9
# step 240, accuracy: 2.06798 , training accuracy 1
# step 250, accuracy: 3.07774 , training accuracy 0.9
# step 260, accuracy: 4.76379 , training accuracy 0.9
# step 270, accuracy: 6.41825 , training accuracy 0.8
# step 280, accuracy: 6.66527 , training accuracy 0.9
# step 290, accuracy: 2.21524 , training accuracy 0.9
# step 300, accuracy: 2.58512 , training accuracy 1
# step 310, accuracy: 11.4525 , training accuracy 0.7
# step 320, accuracy: 0.802516 , training accuracy 1
# step 330, accuracy: 6.43087 , training accuracy 0.8
# step 340, accuracy: 7.4462 , training accuracy 0.8
# step 350, accuracy: 2.72518 , training accuracy 0.9
# step 360, accuracy: 4.99086 , training accuracy 0.9
# step 370, accuracy: 2.45901 , training accuracy 0.9
# step 380, accuracy: 3.33167 , training accuracy 0.8
# step 390, accuracy: 1.83874 , training accuracy 1
# step 400, accuracy: 5.4271 , training accuracy 0.8
# step 410, accuracy: 5.06834 , training accuracy 0.7
# step 420, accuracy: 1.4526 , training accuracy 1
# step 430, accuracy: 2.92529 , training accuracy 0.9
# step 440, accuracy: 4.51694 , training accuracy 0.8
# step 450, accuracy: 0.957429 , training accuracy 1
# step 460, accuracy: 10.8494 , training accuracy 0.6
# step 470, accuracy: 2.84396 , training accuracy 1
# step 480, accuracy: 3.57436 , training accuracy 0.9
# step 490, accuracy: 5.88829 , training accuracy 0.7
# step 500, accuracy: 3.70385 , training accuracy 0.9
# step 510, accuracy: 2.2572 , training accuracy 1
# step 520, accuracy: 1.73905 , training accuracy 1
# step 530, accuracy: 0.48701 , training accuracy 1
# step 540, accuracy: 2.57315 , training accuracy 0.9
# step 550, accuracy: 2.85483 , training accuracy 0.9
# step 560, accuracy: 4.54418 , training accuracy 0.8
# step 570, accuracy: 6.87023 , training accuracy 0.8
# step 580, accuracy: 4.02526 , training accuracy 0.9
# step 590, accuracy: 0.760146 , training accuracy 1
# step 600, accuracy: 1.45713 , training accuracy 1
# step 610, accuracy: 5.05413 , training accuracy 0.8
# step 620, accuracy: 5.34235 , training accuracy 0.9
# step 630, accuracy: 0.876301 , training accuracy 1
# step 640, accuracy: 3.10421 , training accuracy 0.8
# step 650, accuracy: 4.67927 , training accuracy 0.9
# step 660, accuracy: 1.56613 , training accuracy 1
# step 670, accuracy: 1.40358 , training accuracy 1
# step 680, accuracy: 3.67698 , training accuracy 0.9
# step 690, accuracy: 3.4188 , training accuracy 0.9
# step 700, accuracy: 6.02647 , training accuracy 0.9
# step 710, accuracy: 1.42934 , training accuracy 1
# step 720, accuracy: 4.03341 , training accuracy 0.9
# step 730, accuracy: 0.45457 , training accuracy 1
# step 740, accuracy: 0.938955 , training accuracy 1
# step 750, accuracy: 1.05096 , training accuracy 1
# step 760, accuracy: 5.08338 , training accuracy 0.9
# step 770, accuracy: 5.1063 , training accuracy 0.8
# step 780, accuracy: 0.840952 , training accuracy 1
# step 790, accuracy: 3.09376 , training accuracy 0.9
# step 800, accuracy: 8.85043 , training accuracy 0.9
# step 810, accuracy: 0.603108 , training accuracy 1
# step 820, accuracy: 0.441645 , training accuracy 1
# step 830, accuracy: 1.22145 , training accuracy 1
# step 840, accuracy: 5.8601 , training accuracy 0.8
# step 850, accuracy: 3.86278 , training accuracy 0.9
# step 860, accuracy: 0.168934 , training accuracy 1
# step 870, accuracy: 1.43592 , training accuracy 0.9
# step 880, accuracy: 3.28965 , training accuracy 0.9
# step 890, accuracy: 4.58246 , training accuracy 0.9
# step 900, accuracy: 10.5149 , training accuracy 0.7
# step 910, accuracy: 0.892328 , training accuracy 1
# step 920, accuracy: 3.65706 , training accuracy 0.9
# step 930, accuracy: 0.717976 , training accuracy 1
# step 940, accuracy: 0.8 , training accuracy 1
# step 950, accuracy: 0.502668 , training accuracy 1
# step 960, accuracy: 0.650024 , training accuracy 1
# step 970, accuracy: 8.44605 , training accuracy 0.9
# step 980, accuracy: 1.26382 , training accuracy 0.9
# step 990, accuracy: 2.72289 , training accuracy 0.8
# step 1000, accuracy: 1.10007 , training accuracy 1
# step 1010, accuracy: 2.09198 , training accuracy 0.9
# step 1020, accuracy: 0.590503 , training accuracy 1
# step 1030, accuracy: 1.21026 , training accuracy 1
# step 1040, accuracy: 3.91553 , training accuracy 0.9
# step 1050, accuracy: 3.26569 , training accuracy 0.9
# step 1060, accuracy: 1.46228 , training accuracy 0.9
# step 1070, accuracy: 2.80973 , training accuracy 0.9
# step 1080, accuracy: 0.906234 , training accuracy 1
# step 1090, accuracy: 1.94308 , training accuracy 1
# step 1100, accuracy: 1.5407 , training accuracy 1
# step 1110, accuracy: 1.53443 , training accuracy 1
# step 1120, accuracy: 6.89413 , training accuracy 0.8
# step 1130, accuracy: 1.32026 , training accuracy 1
# step 1140, accuracy: 7.34744 , training accuracy 0.8
# step 1150, accuracy: 2.01786 , training accuracy 0.9
# step 1160, accuracy: 3.01881 , training accuracy 0.9
# step 1170, accuracy: 1.42158 , training accuracy 0.9
# step 1180, accuracy: 2.86177 , training accuracy 0.9
# step 1190, accuracy: 0.683987 , training accuracy 1
# step 1200, accuracy: 1.12837 , training accuracy 0.9
# step 1210, accuracy: 0.225636 , training accuracy 1
# step 1220, accuracy: 3.00864 , training accuracy 0.9
# step 1230, accuracy: 2.5473 , training accuracy 0.9
# step 1240, accuracy: 1.15775 , training accuracy 1
# step 1250, accuracy: 1.14297 , training accuracy 1
# step 1260, accuracy: 3.49076 , training accuracy 0.8
# step 1270, accuracy: 3.34084 , training accuracy 0.9
# step 1280, accuracy: 2.02042 , training accuracy 0.9
# step 1290, accuracy: 0.549836 , training accuracy 1
# step 1300, accuracy: 1.29063 , training accuracy 1
# step 1310, accuracy: 1.26438 , training accuracy 0.9
# step 1320, accuracy: 0.923885 , training accuracy 1
# step 1330, accuracy: 2.92712 , training accuracy 0.9
# step 1340, accuracy: 0.879651 , training accuracy 1
# step 1350, accuracy: 0.515643 , training accuracy 1
# step 1360, accuracy: 0.551901 , training accuracy 1
# step 1370, accuracy: 0.341087 , training accuracy 1
# step 1380, accuracy: 3.0451 , training accuracy 0.9
# step 1390, accuracy: 1.00733 , training accuracy 0.9
# step 1400, accuracy: 4.06922 , training accuracy 0.9
# step 1410, accuracy: 0.26414 , training accuracy 1
# step 1420, accuracy: 8.65157 , training accuracy 0.9
# step 1430, accuracy: 2.07463 , training accuracy 0.9
# step 1440, accuracy: 0.376021 , training accuracy 1
# step 1450, accuracy: 1.88681 , training accuracy 0.9
# step 1460, accuracy: 1.00689 , training accuracy 1
# step 1470, accuracy: 1.40206 , training accuracy 1
# step 1480, accuracy: 1.23431 , training accuracy 1
# step 1490, accuracy: 1.83774 , training accuracy 0.9
# step 1500, accuracy: 0.244441 , training accuracy 1
# step 1510, accuracy: 1.15178 , training accuracy 1
# step 1520, accuracy: 1.17639 , training accuracy 0.9
# step 1530, accuracy: 5.21968 , training accuracy 0.8
# step 1540, accuracy: 3.48611 , training accuracy 0.9
# step 1550, accuracy: 2.49533 , training accuracy 0.9
# step 1560, accuracy: 0.599257 , training accuracy 1
# step 1570, accuracy: 0.554428 , training accuracy 1
# step 1580, accuracy: 1.17037 , training accuracy 0.9
# step 1590, accuracy: 0.165417 , training accuracy 1
# step 1600, accuracy: 0.901437 , training accuracy 1
# step 1610, accuracy: 2.046 , training accuracy 0.9
# step 1620, accuracy: 0.864691 , training accuracy 1
# step 1630, accuracy: 1.73466 , training accuracy 0.9
# step 1640, accuracy: 1.47298 , training accuracy 0.9
# step 1650, accuracy: 0.895079 , training accuracy 1
# step 1660, accuracy: 0.119089 , training accuracy 1
# step 1670, accuracy: 1.24572 , training accuracy 0.9
# step 1680, accuracy: 0.929721 , training accuracy 1
# step 1690, accuracy: 0.0332533 , training accuracy 1
# step 1700, accuracy: 1.5903 , training accuracy 0.9
# step 1710, accuracy: 2.09269 , training accuracy 0.9
# step 1720, accuracy: 0.0689648 , training accuracy 1
# step 1730, accuracy: 0.157008 , training accuracy 1
# step 1740, accuracy: 1.68706 , training accuracy 0.9
# step 1750, accuracy: 0.162299 , training accuracy 1
# step 1760, accuracy: 0.665923 , training accuracy 1
# step 1770, accuracy: 5.84509 , training accuracy 0.9
# step 1780, accuracy: 0.277928 , training accuracy 1
# step 1790, accuracy: 3.53132 , training accuracy 0.9
# step 1800, accuracy: 6.65367 , training accuracy 0.8
# step 1810, accuracy: 0.314338 , training accuracy 1
# step 1820, accuracy: 0.927663 , training accuracy 0.9
# step 1830, accuracy: 3.57879 , training accuracy 0.9
# step 1840, accuracy: 1.72765 , training accuracy 0.9
# step 1850, accuracy: 0.102983 , training accuracy 1
# step 1860, accuracy: 5.80996 , training accuracy 0.8
# step 1870, accuracy: 0.817541 , training accuracy 1
# step 1880, accuracy: 2.29572 , training accuracy 0.9
# step 1890, accuracy: 1.0982 , training accuracy 0.9
# step 1900, accuracy: 0.180525 , training accuracy 1
# step 1910, accuracy: 4.60486 , training accuracy 0.9
# step 1920, accuracy: 0.560368 , training accuracy 1
# step 1930, accuracy: 0.361681 , training accuracy 1
# step 1940, accuracy: 0.422767 , training accuracy 1
# step 1950, accuracy: 1.75383 , training accuracy 0.9
# step 1960, accuracy: 4.33665 , training accuracy 0.8
# step 1970, accuracy: 0.392861 , training accuracy 1
# step 1980, accuracy: 0.70476 , training accuracy 1
# step 1990, accuracy: 0.516399 , training accuracy 1

# %%
test_x,test_y=mnist.train.next_batch(15)
# print(test_x)
print(corrcet_result.eval(feed_dict={x:test_x,keep_prob: 1.0}))
fig = plt.figure()
for i in range(0,15,1):
    image=test_x[i].reshape(28,28)
    lable=np.argmax(test_y[i])
    plt.subplot(3,5,i+1) # 绘制前15个手写体数字，以3行6列子图形式展示
    plt.tight_layout() # 自动适配
    plt.imshow(image, cmap='Greys') # 使用灰色显示像素灰度值
    plt.title("Label: {}".format(lable)) # 设置标签为子图标题
# Out:
# [3 9 1 2 6 2 1 0 3 3 0 2 6 0 3]
