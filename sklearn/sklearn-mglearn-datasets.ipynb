# %%
import numpy as np
import  matplotlib.pyplot as plt 
import pandas as pd
import mglearn

# %%
x,y=mglearn.datasets.make_forge()
# print(x,y)
mglearn.discrete_scatter(x[:,0],x[:,1],y)
plt.legend(["class 0","class 1"],loc=4)
plt.xlabel("fisrt feature")
plt.xlabel("second feature")
print("x.shape:{}".format(x.shape))
# Out:
# d:\python36\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=FutureWarning)
# x.shape:(26, 2)
